# %% [markdown]
# # Xoron-Dev Automation
# This notebook clones the repository, installs dependencies, and executes the build script.

# %%
# !git clone -b beta --single-branch https://github.com/nigfuapp-web/Xoron-Dev.git && echo "Clone done"
# Out:
# Cloning into 'Xoron-Dev'...
# remote: Enumerating objects: 2384, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 2384 (delta 151), reused 166 (delta 143), pack-reused 2197 (from 2)
# Receiving objects: 100% (2384/2384), 4.61 MiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (1533/1533), done.
# Clone done

# %%
# 2. Change directory into the project folder
# %cd Xoron-Dev
# Out:
# /kaggle/working/Xoron-Dev

# %%
# !pip install -r requirements.txt && echo "Dependencies installed successfully!"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 MB 31.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 48.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.16-cp312-cp312-linux_x86_64.whl size=4503241 sha256=225eec0613814f6435d26d4754ab997bc2966667e7c5af2d50421406ea72ecd5
# ...

# %%
# !export PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# 4. Execute the build script
# !python build.py --hf --text --max-image 3300
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/Xoron-Dev/build.py", line 36, in <module>
#     from config import (
# ImportError: cannot import name 'get_format_functions' from 'config' (/kaggle/working/Xoron-Dev/config/__init__.py)
